# %% [markdown]
# # Active thermal cooling test case
#
# #### *Paper*:        Real-time optimal control of high-dimensional parametrized systems by deep learning-based reduced order models
# #### *Authors*:      M.Tomasetto, F.Braghin, A.Manzoni
# #### *Affiliations*: Department of Mechanical Engineering (Politecnico di Milano), MOX - Department of Mathematics (Politecnico di Milano)

# %%
#IMPORT LIBRARIES

from dolfin import *
from dolfin_adjoint import *
import gmsh
import torch
import numpy as np
import matplotlib.pyplot as plt
from __future__ import print_function
from IPython.display import clear_output as clc

from dlroms.cores import CPU, GPU # Cores swapping
import dlroms.fespaces as fe # Finite element spaces handling
import dlroms.geometry as geo # Mesh creation
from dlroms.roms import num2p # Percentage format

import seaborn as sns
teal = sns.light_palette("teal", 15)
magenta = sns.dark_palette("magenta", 15)
red = sns.light_palette("orangered", 15)
navy = sns.light_palette("navy", 15)

set_log_level(LogLevel.ERROR)

# %% [markdown]
# # State problem
#  Steady heat equation
# $$
# \begin{equation}
#     \begin{cases}
#        - \mu \Delta q = s(\boldsymbol{\mu}_s) + u{1}_{\Omega_c}  \qquad &\mathrm{in} \ \Omega \\
#        - \mu \nabla q \mathbf{n} = q  \qquad &\mathrm{on} \ \Gamma_{\mathrm{d}} \\
#         - \mu \nabla q \mathbf{n} = h (q - q_{\mathrm{ext}})  \qquad &\mathrm{on} \ \Gamma_{\mathrm{obs}}
# \end{cases}
# \end{equation}
# $$
#
# where $\Omega$ is the domain of interest, $q$ is the unknown temperature field, $u$ is the control variable that specifies the source term in the annular region around the obstacle $\Omega_c$, $s$ is the external source term depending on scenario parameters $\boldsymbol{\mu}_s$, $\mu$ is the thermal diffusivity, $h$ is the heat transfer coefficient, $q_{\mathrm{ext}}$ is the environment temperature, $\mathbf{n}$ is the normal versor

# %%
# CREATE THE MESH FOR THE STATE PROBLEM

domain = geo.Rectangle((-1,-1),(1,1)) - geo.Circle((0.0, 0.0), 0.15)
mesh = geo.mesh(domain, stepsize = 0.01)

# Refine the mesh in the control region
class OmegaC(SubDomain): # Control region
    def inside(self, x, on_boundary):
        return x[0]*x[0] + x[1]*x[1] > 0.2 * 0.2 and x[0]*x[0] + x[1]*x[1] < 0.3 * 0.3
domains_bool = MeshFunction("bool", mesh, mesh.geometric_dimension())
domains_bool.set_all(False)
OmegaC().mark(domains_bool, True)
mesh = refine(mesh, domains_bool)

plot(mesh)
plt.title("Mesh ($N_{h}$=%d)" % mesh.num_vertices());
plt.axis('off');

# %%
# DEFINE AND MARK SUBDOMAINS AND BOUNDARY PORTIONS

domains = MeshFunction("size_t", mesh, mesh.geometric_dimension())
OmegaC().mark(domains, 1)
dx = Measure("dx", domain = mesh, subdomain_data = domains) # Domain measure

class GammaD(SubDomain): # External boundary
    def inside(self, x, on_boundary):
        return on_boundary and (near(x[0], -1.0) or near(x[0], 1.0) or near(x[1], -1.0) or near(x[1], 1.0))
class GammaOBS(SubDomain): # Obstacle boundary
    def inside(self, x, on_boundary):
        d = sqrt(x[0]*x[0] + x[1]*x[1])
        return on_boundary and d <= 0.15 + DOLFIN_EPS
boundaries = MeshFunction("size_t", mesh, mesh.topology().dim() - 1)
GammaD().mark(boundaries, 1)
GammaOBS().mark(boundaries, 2)
ds = Measure("ds", domain = mesh, subdomain_data = boundaries) # Boundary measure

# %%
# DEFINE THE SPACE STATE

space = fe.space(mesh, 'CG', 1) # State space
clc()

nh = space.dim() # State space dimension

# %%
# DEFINE MESH ON CONTROL REGION

domain_control = geo.Circle((0.0, 0.0), 0.3) - geo.Circle((0.0, 0.0), 0.2)
mesh_control = geo.mesh(domain_control, stepsize = 0.005)
space_control = fe.space(mesh_control, 'CG', 1)
dx_control = Measure("dx", domain = mesh_control) # Control region measure

nu = space_control.dim() # Control region dimension

plot(mesh_control)
plt.title("Mesh on control region ($N_{u}$=%d)" % mesh_control.num_vertices());
plt.axis("off");

# %%
# GET INDICES FOR THE CONTROL

bc_dummy = DirichletBC(space, 1.0, boundaries, 2)
fun_dummy = Function(space)
bc_dummy.apply(fun_dummy.vector())

idx_obstacle = fun_dummy.vector() == 1

# %%
# DEFINE THE STATE PROBLEM SOLVER

mu = 1.0

def compute_state(theta_source, r_source, u):
    """
    Solve the steady heat equation
    Input: scenario parameters, i.e. the coordinates of the source, and control function
    Output: state function     
    """
    # Solve state equation
    int_source = 5000.0
    var_source = 0.025
    x_source = r_source * cos(theta_source)
    y_source = r_source * sin(theta_source)
    q_ext = int_source * var_source
    h = 1.0 # (heat transfer coefficient) * (volumetric heat capacity)
    
    s = Expression('int_source * exp(-((x[0] - x_source)*(x[0] - x_source) + (x[1] - y_source)*(x[1] - y_source)) / var_source)', degree = 1, int_source = int_source, x_source = x_source, y_source = y_source, var_source = var_source)
    
    q = TrialFunction(space)
    v = TestFunction(space)
    u.set_allow_extrapolation(True)
       
    a = mu * inner(grad(q), grad(v)) * dx + inner(q, v) * ds(1) + h * inner(q, v) * ds(2) 
    L = s * v * dx + u * v * dx(1) + h * q_ext * v * ds(2)
    
    q = Function(space)
    solve(a == L, q)
    
    return q

# %%
# SOLVE THE STATE PROBLEM

u = interpolate(Expression('0.0', degree = 1), space_control)

q = compute_state(theta_source = 0.0, r_source = 0.75, u = u)

print(f"Mean temperature on the obstacle boundary: {q.vector()[idx_obstacle].mean()}")

fig_dummy = plot(q, mode = "color", cmap = "inferno")
fig = plot(q, cmap = "inferno")
plt.colorbar(fig_dummy)
plt.title("Uncontrolled state");
plt.axis('off');
# Out:
# Mean temperature on the obstacle boundary: 90.13807061292513

# %%
# DEFINE A FUNCTION TO PLOT THE OBSTACLE TEMPERATURE VALUES

def plot_qOBS(q, q_opt = None):
    """
    Plot the temperature values on the obstacle boundary
    """
    
    vals = [q(0.15 * cos(a), 0.15 * sin(a)) for a in np.linspace(0, 2*pi, 200)]
    plt.plot([a for a in np.linspace(0, 2*pi, 200)], vals, label = "$q_{\mathrm{obs}}$", color = teal[14], linewidth = 3)
    
    if(q_opt != None):
        vals_opt = [q_opt(0.15 * cos(a), 0.15 * sin(a)) for a in np.linspace(0, 2*pi, 200)]
        plt.plot([a for a in np.linspace(0, 2*pi, 200)], vals_opt, label = "$q^*_{\mathrm{obs}}$", color = magenta[5], linewidth = 3)

    plt.plot([a for a in np.linspace(0, 2*pi, 200)], CPU.zeros(len(vals)), '--', linewidth = 1, color = "darkgray", label = "$q = 0.0$")
    plt.legend(loc = "best", fontsize=12)
    plt.xlabel(r"$\beta$", fontsize=15)
    plt.ylabel(r"$q$", fontsize=15)
    plt.title("Temperature on obstacle boundary");

# %%
# UNCONTROLLED OBSTACLE TEMPERATURES (PLOT)

plot_qOBS(q)

# %% [markdown]
# # Optimization with FOM

# %%
# SOLVE THE OPTIMAL CONTROL PROBLEM

theta_source = 0.0
r_source = 0.75
beta = 1e-8

set_working_tape(Tape()) # Reset forward model annotated by dolfin adjoint

u = interpolate(Expression('0.0', degree = 1), space)

q = compute_state(theta_source, r_source, u)

J = assemble(inner(q, q) * ds(2) +  beta * inner(u,u) * dx(1) +  beta * inner(grad(u),grad(u)) * dx(1))
control = Control(u)
Jhat = ReducedFunctional(J, control)

u_opt = minimize(Jhat, method ="L-BFGS-B", tol = 1e-10, options = {'disp': True, "maxiter":10000, 'ftol': 1e-10, 'gtol': 1e-10})   
q_opt = compute_state(theta_source, r_source, u_opt)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =        51665     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.86036D+03    |proj g|=  1.14148D-03
#  This problem is unconstrained.
# At iterate    1    f=  6.28212D+03    |proj g|=  1.02583D-03
#
# At iterate    2    f=  1.41781D+02    |proj g|=  9.88619D-05
#
# At iterate    3    f=  1.14524D+02    |proj g|=  8.39619D-05
#
# At iterate    4    f=  4.64029D+00    |proj g|=  6.05401D-05
#
# At iterate    5    f=  2.69535D+00    |proj g|=  1.52832D-05
#
# At iterate    6    f=  2.31560D+00    |proj g|=  1.33803D-05
#
# At iterate    7    f=  1.27023D+00    |proj g|=  6.32870D-06
#
# At iterate    8    f=  8.22864D-01    |proj g|=  4.11282D-05
#
# At iterate    9    f=  4.43034D-01    |proj g|=  5.69589D-06
#
# At iterate   10    f=  3.29788D-01    |proj g|=  3.99836D-06
#
# At iterate   11    f=  2.39567D-01    |proj g|=  4.64591D-06
#
# ...

# %%
# OPTIMAL PAIR (PLOT)

plt.figure(figsize = (10,10))

plt.subplot(1,2,1)
fig_dummy = plot(q_opt, mode = "color", cmap = "inferno")
fig = plot(q_opt, cmap = "inferno")
plt.colorbar(fig_dummy, shrink = 0.4)
plt.title("Optimal state");
plt.axis('off');

plt.subplot(1,2,2)
u_opt_plot = interpolate(u_opt, space_control)
fig_dummy = plot(u_opt_plot, mode = "color", cmap = "inferno")
fig = plot(u_opt_plot, cmap = "inferno")
plt.colorbar(fig_dummy, shrink = 0.4)
plt.title("Optimal control");
plt.axis('off');
plt.xlim(-0.3, 0.3)
plt.ylim(-0.3, 0.3)

print(f"Mean relative error on the obstacle temperature: {num2p(q_opt.vector()[idx_obstacle].mean())}")
# Out:
# Mean relative error on the obstacle temperature: 0.01%

# %%
# UNCONTROLLED vs OPTIMAL OBSTACLE TEMPERATURES (PLOT)

plot_qOBS(q, q_opt)

# %% [markdown]
# # Snapshots generation

# %% [markdown]
# ### PDE-constrained Optimisation
#
# Consider the problem of minimising the temperature on the obstacle boundary
#
# $$
# \min_{q,u} \int_{\Gamma_{\text{obs}}} |q|^2 + \beta \int_{\Omega_{\textrm{c}}} |u|^2  + \beta_g \int_{\Omega_{\textrm{c}}} ||\nabla u||^2  \\
# $$

# %%
# SNAPSHOTS GENERATION

nsnapshots = 100
ntrain = 80
nparams = 2

beta = 0.0000001
betag = 0.0000001

theta_source_range = (-pi/2, pi/2)
r_source_range = (0.4, 0.9)

Q = CPU.zeros(nsnapshots, nh)       # Matrix for the state snapshots
U = CPU.zeros(nsnapshots, nu)       # Matrix for the control snapshots
MU = CPU.zeros(nsnapshots, nparams) # Matrix for the scenario parameter

set_working_tape(Tape()) # Reset forward model annotated by dolfin adjoint

for i in range(nsnapshots):
    print("Snapshots number ", i)

    theta_source, r_source = CPU.rand(), CPU.rand()
    theta_source = (theta_source_range[1] - theta_source_range[0]) * theta_source.item() + theta_source_range[0]
    r_source = (r_source_range[1] - r_source_range[0]) * r_source.item() + r_source_range[0]
    
    u = interpolate(Expression('0.0', degree = 1), space)
    
    q = compute_state(theta_source, r_source, u)

    # Solve optimal control problem
    J = assemble(inner(q, q) * ds(2) +  beta * inner(u,u) * dx(1) +  betag * inner(grad(u),grad(u)) * dx(1))  
    control = Control(u)
    Jhat = ReducedFunctional(J, control)
    
    u_opt = minimize(Jhat, method ="L-BFGS-B", tol = 1e-10, options = {'disp': True, "maxiter":1000, 'ftol': 1e-10, 'gtol': 1e-10})
    q_opt = compute_state(theta_source, r_source, u_opt)

    set_working_tape(Tape()) # Reset forward model annotated by dolfin adjoint

    # Save the results
    Q[i] = CPU.tensor(q_opt.vector())
    U[i] = CPU.tensor(interpolate(u_opt, space_control).vector())
    MU[i, 0] = CPU.tensor(theta_source)
    MU[i, 1] = CPU.tensor(r_source)
    
    clc()
        
torch.save(Q, 'Data/Cooling/Q.pt')
torch.save(U, 'Data/Cooling/U.pt')
torch.save(MU,'Data/Cooling/MU.pt')

# %%
# LOAD SNAPSHOTS MATRICES

nsnapshots = 100
ntrain = 80
nparams = 2

theta_source_range = (-pi/2, pi/2)
r_source_range = (0.4, 0.9)

Q = CPU.zeros(nsnapshots, nh)       # Matrix for the state snapshots
U = CPU.zeros(nsnapshots, nu)       # Matrix for the control snapshots
MU = CPU.zeros(nsnapshots, nparams) # Matrix for the scenario parameter

Q = torch.load('Data/Cooling/Q.pt')
U = torch.load('Data/Cooling/U.pt')
MU = torch.load('Data/Cooling/MU.pt')

# %%
# SNAPSHOT EXAMPLE (PLOT)

which = 0

plt.figure(figsize = (10,10))

plt.subplot(1,2,1)
fig = fe.plot(Q[which], space, levelcurves = True, colorbar = True, shrink = 0.365, cmap = "inferno")
plt.title("Optimal state snapshot");

plt.subplot(1,2,2)
fig = fe.plot(U[which], space_control, levelcurves = True, colorbar = True, shrink = 0.365, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno")
plt.title("Optimal control snapshot");

# %%
# UNCONTROLLED vs OPTIMAL OBSTACLE TEMPERATURES (PLOT)

which = 0

u = interpolate(Expression('0.0', degree = 1), space_control)
q = compute_state(theta_source = MU[which,0].item(), r_source = MU[which,1].item(), u = u)
plot_qOBS(q, fe.asvector(Q[which], space))

# %% [markdown]
# # POD-DL-ROM

# %%
# IMPORT FUNCTIONS FOR POD AND NEURAL NETWORKS

from dlroms.dnns import Dense, train, Weightless # Neural networks handling
from dlroms.roms import POD, projectup, projectdown # Proper orthogonal decomposition

# %%
# DEFINE THE ERROR FUNCTIONS 

def mse(true, pred):
    return (true - pred).pow(2).sum(axis = -1).mean()

def rmse(true, pred):
    return (true - pred).pow(2).sum(axis = -1).sqrt().mean()

def mre(true, pred):
    return (true - pred).pow(2).sum(axis = -1).mean() / (pred.pow(2).sum(axis = -1).mean())

def l2_state(Q):
    l2_norms = CPU.zeros(Q.shape[0])
    for i in range(Q.shape[0]):
        q = fe.asvector(Q[i], space)
        l2_norms[i] = sqrt(assemble(inner(q, q) * dx))
    return l2_norms

def l2_state_mse(true, pred):
    return (l2_state(true - pred)).mean()

def l2_state_mre(true, pred):
    return (l2_state(true - pred) / l2_state(true)).mean()

def l2_control(U):
    l2_norms = CPU.zeros(U.shape[0])
    for i in range(U.shape[0]):
        u = fe.asvector(U[i], space_control)
        l2_norms[i] = sqrt(dolfin.assemble(inner(u, u) * dx_control))
    return l2_norms

def l2_control_mse(true, pred):
    return (l2_control(true - pred)).mean()

def l2_control_mre(true, pred):
    return (l2_control(true - pred) / l2_control(true)).mean()

def linf(x):
    return x.abs().max(axis = -1)[0]

def linf_mse(true, pred):
    return (linf(true - pred)).mean()

def linf_mre(true, pred):
    return (linf(true - pred) / linf(true)).mean()

# %% [markdown]
# ## Control reduction - POD

# %%
# PRINCIPAL ORTHOGONAL DECOMPOSITION FOR U

k_U = 7 # Number of modes
pod_U, eig_U = POD(U[:ntrain], k = k_U)
U_POD = projectdown(pod_U, U).squeeze(-1)

plt.plot([i for i in range(1, k_U + 1)], eig_U, color = teal[5], marker = 's', markersize = 5, linewidth = 1)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.scatter(7, eig_U[6], color = teal[5], marker = 's', facecolors = 'none', linestyle='--', s = 100)
plt.ylabel("${\sigma_{\mathrm{i}}}^{u}$", fontsize=15)
plt.title("Singular values decay");

# %%
# POD RECONSTRUCTION ERRORS ON TEST DATA

U_reconstructed = projectup(pod_U, U_POD)

print("POD reconstruction errors:")
print("")
print("Mean relative error on U: %s." % num2p(mre(U[ntrain:], U_reconstructed[ntrain:])))
print("L2 mean relative error on U: %s." % num2p(l2_control_mre(U[ntrain:], U_reconstructed[ntrain:])))
print("Linf mean relative error on U: %s." % num2p(linf_mre(U[ntrain:], U_reconstructed[ntrain:])))
# Out:
# POD reconstruction errors:
#
# Mean relative error on U: 0.00%.
# L2 mean relative error on U: 0.17%.
# Linf mean relative error on U: 0.14%.

# %%
# FIRST POD MODE (PLOT)

fe.plot(pod_U[0], space_control, levelcurves = True, colorbar = True, shrink = 1, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno")
plt.title("First POD mode");

# %%
# FOM vs POD RECONSTRUCTION (PLOTS)

which = -1

qmin = min(U[which].min(), U_reconstructed[which].min())
qmax = max(U[which].max(), U_reconstructed[which].max())

plt.figure(figsize = (20,20))

plt.subplot(1,3,1)
fe.plot(U[which], space_control, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno") 
plt.title("Optimal control snapshot");

plt.subplot(1,3,2)
fe.plot(U_reconstructed[which], space_control, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno") 
plt.title("POD reconstruction");

plt.subplot(1,3,3)
fe.plot(((U[which] - U_reconstructed[which])**2).sqrt(), space_control, colorbar = True, shrink = 0.235, vmin = 0.0, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno") 
plt.title("Reconstruction error");

# %% [markdown]
# ## State reduction - POD+AE

# %%
# PRINCIPAL ORTHOGONAL DECOMPOSITION FOR V

k_Q = 72 # Number of modes
pod_Q, eig_Q = POD(Q[:ntrain], k = k_Q)
Q_POD = projectdown(pod_Q, Q).squeeze(-1)

plt.plot([i for i in range(1, k_Q + 1)], eig_Q, color = teal[14], marker = 's', markersize = 5, linewidth = 1)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.scatter(72, eig_Q[71], color = teal[14], marker = 's', facecolors = 'none', linestyle='--', s = 100)
plt.ylabel("${\sigma_{\mathrm{i}}}^{y}$", fontsize=15)
plt.title("Singular values decay");

# %%
# AUTOENCODER FOR REDUCTION

n_Q = 6 # Latent dimension
encoder = Dense(k_Q, 70) + Dense(70, 25) + Dense(25, n_Q)
decoder = Dense(n_Q, 25) + Dense(25, 50) + Dense(50, 70) + Dense(70, k_Q, activation = None)
autoencoder = encoder + decoder

autoencoder.He() # NN initialization
train(autoencoder, Q_POD, Q_POD, ntrain, epochs = 1000, optim = torch.optim.LBFGS, lossf = mse, error = mre, best = True)

# %%
# LOAD THE AUTOENCODER

n_Q = 6 # Latent dimension
encoder = Dense(k_Q, 70) + Dense(70, 30) + Dense(30, n_Q)
decoder = Dense(n_Q, 30) + Dense(30, 50) + Dense(50, 70) + Dense(70, k_Q, activation = None)
autoencoder = encoder + decoder

autoencoder.load_state_dict(torch.load('NN/Cooling/autoencoder.pt'))
autoencoder.eval()

clc()

# %%
# POD+AE RECONSTRUCTION ERRORS ON TEST DATA

autoencoder.freeze()
Q_DLROM = encoder(Q_POD)
Q_reconstructed = projectup(pod_Q, decoder(Q_DLROM))

print("Mean relative error: %s." % num2p(mre(Q[ntrain:], Q_reconstructed[ntrain:])))
print("L2 mean relative error: %s." % num2p(l2_state_mre(Q[ntrain:], Q_reconstructed[ntrain:])))
print("Linf mean relative error: %s." % num2p(linf_mre(Q[ntrain:], Q_reconstructed[ntrain:])))
# Out:
# Mean relative error: 0.05%.
# L2 mean relative error: 2.00%.
# Linf mean relative error: 2.99%.

# %%
# FOM vs POD+AE RECONSTRUCTION (PLOTS)

which = -1

qmin = min(Q[which].min(), Q_reconstructed[which].min())
qmax = max(Q[which].max(), Q_reconstructed[which].max())

plt.figure(figsize = (20,20))

plt.subplot(1,3,1)
fe.plot(Q[which], space, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, cmap = "inferno")
plt.title("Optimal state snapshots");

plt.subplot(1,3,2)
fe.plot(Q_reconstructed[which], space, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, cmap = "inferno") 
plt.title("POD+AE reconstruction");

plt.subplot(1,3,3)
fe.plot(((Q[which] - Q_reconstructed[which])**2).sqrt(), space, colorbar = True, shrink = 0.235, xlim = (-1, 1), ylim = (-1, 1), cmap = "inferno")
plt.title("Reconstruction error");

# %% [markdown]
# ## Parameter-to-solution map $\boldsymbol{\mu}_s \to ( \mathbf{u}_{POD}, \mathbf{y}_{POD+AE} )$

# %%
# NORMALIZATION OF THE INPUT/OUTPUT MATRICES 

QDLROMmin = Q_DLROM.min()
QDLROMmax = Q_DLROM.max()
Q_DLROM_std = (Q_DLROM - QDLROMmin) / (QDLROMmax - QDLROMmin)

UPODmax = U_POD.min()
UPODmin = U_POD.max()
U_POD_std = (U_POD - UPODmin) / (UPODmax - UPODmin)

QU_DLROM_std = torch.cat((Q_DLROM_std, U_POD_std), 1)

# %%
# NN TO MAP PARAMETERS IN REDUCED OPTIMAL STATE AND CONTROL

class Embedd(Weightless): # First layer with some fixed transformation of the input (driven by the problem)
    def forward(self, x):
        return torch.cat([x, x[:,[0]].cos(), x[:,[1]]*x[:,[0]].cos(), x[:,[0]].sin(), x[:,[1]]*x[:,[0]].sin()], axis = 1)
                         
phi = Embedd() + Dense(6,  50) + Dense(50, 50) + Dense(50, QU_DLROM_std.shape[1], activation = None)
phi.He() # Random initialization

train(phi, MU, QU_DLROM_std, ntrain = ntrain, epochs = 2000, optim = torch.optim.LBFGS, lossf = mse, error = mre, best = True)

# %%
# LOAD THE NN THAT MAPS PARAMETERS IN REDUCED OPTIMAL STATE AND CONTROL

class Embedd(Weightless): # First layer with some fixed transformation of the input (driven by the problem)
    def forward(self, x):
        return torch.cat([x, x[:,[0]].cos(), x[:,[1]]*x[:,[0]].cos(), x[:,[0]].sin(), x[:,[1]]*x[:,[0]].sin()], axis = 1)
                         
phi = Embedd() + Dense(6,  50) + Dense(50, 50) + Dense(50, QU_DLROM_std.shape[1], activation = None)
phi.load_state_dict(torch.load('NN/Cooling/phi.pt'))
phi.eval()

clc()

# %%
# POD-DL-ROM PREDICTION ERRORS ON TEST DATA

phi.freeze()

QU_DLROM_std_hat = phi(MU)
Q_DLROM_hat = QU_DLROM_std_hat[:,:n_Q] * (QDLROMmax - QDLROMmin) + QDLROMmin
U_POD_hat = QU_DLROM_std_hat[:,n_Q:] * (UPODmax - UPODmin) + UPODmin

Q_hat = projectup(pod_Q, decoder(Q_DLROM_hat))
U_hat = projectup(pod_U, U_POD_hat)

print("POD-DL-ROM prediction errors:")
print("")
print("Mean relative error on Q: %s." % num2p(mre(Q[ntrain:], Q_hat[ntrain:])))
print("L2 mean relative error on Q: %s." % num2p(l2_state_mre(Q[ntrain:], Q_hat[ntrain:])))
print("Linf mean relative error on Q: %s." % num2p(linf_mre(Q[ntrain:], Q_hat[ntrain:])))
print("")
print("Mean relative error on U: %s." % num2p(mre(U[ntrain:], U_hat[ntrain:])))
print("L2 mean relative error on U: %s." % num2p(l2_control_mre(U[ntrain:], U_hat[ntrain:])))
print("Linf mean relative error on U: %s." % num2p(linf_mre(U[ntrain:], U_hat[ntrain:])))
# Out:
# POD-DL-ROM prediction errors:
#
# Mean relative error on Q: 0.21%.
# L2 mean relative error on Q: 3.83%.
# Linf mean relative error on Q: 5.67%.
#
# Mean relative error on U: 0.01%.
# L2 mean relative error on U: 1.10%.
# Linf mean relative error on U: 1.22%.

# %%
# OBSTACLE TEMPERATURE ERROR

vals_ROM = [q[idx_obstacle].mean() for q in Q_hat[ntrain:]]
print(f"Mean relative error on the obstacle temperature: {num2p(sum(vals_ROM) / len(vals_ROM))}")
# Out:
# Mean relative error on the obstacle temperature: 0.11%

# %%
# FOM vs POD-DL-ROM PREDICTION (PLOTS)

which = -1

qmin = min(Q[which].min(), Q_hat[which].min())
qmax = max(Q[which].max(), Q_hat[which].max())

plt.figure(figsize = (20,20))

plt.subplot(1,3,1)
fe.plot(Q[which], space, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, cmap = "inferno")
plt.title("Optimal state snapshots");

plt.subplot(1,3,2)
fe.plot(Q_hat[which], space, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, cmap = "inferno") 
plt.title("POD-DL-ROM prediction");

plt.subplot(1,3,3)
fe.plot(((Q[which] - Q_hat[which])**2).sqrt(), space, colorbar = True, shrink = 0.235, xlim = (-1, 1), ylim = (-1, 1), cmap = "inferno")
plt.title("Prediction error");

# %%
# FOM vs POD-DL-ROM PREDICTION (PLOTS)

which = -1

qmin = min(U[which].min(), U_hat[which].min())
qmax = max(U[which].max(), U_hat[which].max())

plt.figure(figsize = (20,20))

plt.subplot(1,3,1)
fe.plot(U[which], space_control, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno")
plt.title("Optimal control snapshots");

plt.subplot(1,3,2)
fe.plot(U_hat[which], space_control, vmin = qmin, vmax = qmax, levelcurves = True, colorbar = True, shrink = 0.235, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno") 
plt.title("POD-DL-ROM prediction");

plt.subplot(1,3,3)
fe.plot(((U[which] - U_hat[which])**2).sqrt(), space_control, colorbar = True, shrink = 0.235, vmin = 0.0, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno")
plt.title("Prediction error");

# %% [markdown]
# # Test case: solve the OCP for different source positions

# %%
# CREATE TEST PARAMETERS

dtheta_source_test = 0.05 # Difference between theta_source of consecutive source positions 
npos = round(pi / dtheta_source_test) - 1 # Number of source positions to investigate
r_source_test = 0.65 # Distance between source and obstacle fixed

MU_test = CPU.zeros(npos, nparams)

for j in range(npos):
    MU_test[j,0] = -pi/2 + (j + 1) * float(dtheta_source_test)
    MU_test[j,1] = r_source_test
    clc()

# %%
# COMPUTE OPTIMAL STATE AND CONTROL

QU_DLROM_std_test_hat = phi(MU_test)

Q_DLROM_test_hat = QU_DLROM_std_test_hat[:,:n_Q] * (QDLROMmax - QDLROMmin) + QDLROMmin
U_POD_test_hat = QU_DLROM_std_test_hat[:,n_Q:(n_Q + k_U)] * (UPODmax - UPODmin) + UPODmin

Q_test_hat = projectup(pod_Q, decoder(Q_DLROM_test_hat))
U_test_hat = projectup(pod_U, U_POD_test_hat)

# %%
# POD-DL-ROM PREDICTION (PLOT)

which = 20

plt.figure(figsize = (10,10))

plt.subplot(1,2,1)
fe.plot(Q_test_hat[which], space, levelcurves = True, colorbar = True, shrink = 0.365, cmap = "inferno")
plt.title("POD-DL-ROM optimal state prediction");

plt.subplot(1,2,2)
fe.plot(U_test_hat[which], space_control, levelcurves = True, colorbar = True, shrink = 0.365, xlim = (-0.3, 0.3), ylim = (-0.3, 0.3), cmap = "inferno")
plt.title("POD-DL-ROM optimal control prediction");
